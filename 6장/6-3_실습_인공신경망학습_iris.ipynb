# %% [markdown]
# # 6.3 실습 - 인공신경망 학습
#
# ## 6.3.1 인공신경망 학습하기 - 기본

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
tf.__version__
# Out:
# '2.8.0'

# %%
# 데이터 불러오기
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['label'] = iris.target

# %%
# 데이터분할
y = df['label']
X = df.drop(['label'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
X_train.shape
# Out:
# (112, 4)

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(8, input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %%
# 모델 컴파일
model.compile(loss='sparse_categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 40
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 67
# Trainable params: 67
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 실행
model.fit(X_train, y_train, epochs=50, batch_size=4)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 1s 4ms/step - loss: 4.5499 - accuracy: 0.3304
# Epoch 2/50
# 28/28 [==============================] - 0s 5ms/step - loss: 2.9994 - accuracy: 0.3304
# Epoch 3/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1.6919 - accuracy: 0.3304
# Epoch 4/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1.0721 - accuracy: 0.6518
# Epoch 5/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.9308 - accuracy: 0.6071
# Epoch 6/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.8604 - accuracy: 0.6071
# Epoch 7/50
# 28/28 [==============================] - 0s 5ms/step - loss: 0.8123 - accuracy: 0.5446
# Epoch 8/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.7603 - accuracy: 0.6429
# Epoch 9/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7212 - accuracy: 0.6875
# Epoch 10/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.6964
# Epoch 11/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6527 - accuracy: 0.6964
# Epoch 12/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6260 - accuracy: 0.7500
# Epoch 13/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5989 - accuracy: 0.7768
# Epoch 14/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5774 - accuracy: 0.7679
# Epoch 15/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5539 - accuracy: 0.8482
# Epoch 16/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5370 - accuracy: 0.8393
# Epoch 17/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5186 - accuracy: 0.8571
# Epoch 18/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5006 - accuracy: 0.8750
# Epoch 19/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4877 - accuracy: 0.9018
# Epoch 20/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4778 - accuracy: 0.8571
# Epoch 21/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4595 - accuracy: 0.9018
# Epoch 22/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4517 - accuracy: 0.9196
# Epoch 23/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.8482
# Epoch 24/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.9554
# Epoch 25/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4223 - accuracy: 0.9196
# Epoch 26/50
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4105 - accuracy: 0.8929
# Epoch 27/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4022 - accuracy: 0.9554
# Epoch 28/50
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3909 - accuracy: 0.9464
# Epoch 29/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3851 - accuracy: 0.9018
# Epoch 30/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.9107
# Epoch 31/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3709 - accuracy: 0.9286
# Epoch 32/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3617 - accuracy: 0.9464
# Epoch 33/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.9554
# Epoch 34/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.9375
# Epoch 35/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3401 - accuracy: 0.9732
# Epoch 36/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3411 - accuracy: 0.9643
# Epoch 37/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3252 - accuracy: 0.9464
# Epoch 38/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3207 - accuracy: 0.9375
# Epoch 39/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3120 - accuracy: 0.9643
# Epoch 40/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.3042 - accuracy: 0.9821
# Epoch 41/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3068 - accuracy: 0.9286
# Epoch 42/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2928 - accuracy: 0.9643
# Epoch 43/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2895 - accuracy: 0.9643
# Epoch 44/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2806 - accuracy: 0.9821
# Epoch 45/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2788 - accuracy: 0.9554
# Epoch 46/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2715 - accuracy: 0.9732
# Epoch 47/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.2667 - accuracy: 0.9732
# Epoch 48/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2626 - accuracy: 0.9643
# Epoch 49/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2577 - accuracy: 0.9643
# Epoch 50/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2523 - accuracy: 0.9732

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2943 - accuracy: 0.9474
# [0.29427745938301086, 0.9473684430122375]

# %%
model.predict(X_test)[0]
# Out:
# array([9.5048684e-01, 4.9232934e-02, 2.8022332e-04], dtype=float32)

# %%
# 테스트 데이터로 예측한 값이 가장 큰 값을 반환(argmax)한 결과
np.argmax(model.predict(X_test)[0])
# Out:
# 0

# %%
# 테스트셋의 실제값
y_test.iloc[0]
# Out:
# 0

# %% [markdown]
# ### 전체 소스 코드

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 데이터 불러오기
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['label'] = iris.target

# 데이터분할
y = df['label']
X = df.drop(['label'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# 모델의 설정
model = Sequential()
model.add(Dense(8, input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 모델 컴파일
model.compile(loss='sparse_categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

# 모델 실행
model.fit(X_train, y_train, epochs=50, batch_size=4)

# 모델 평가
model.evaluate(X_test, y_test)

# 값 예측
model.predict(X_test)[0]
# Out:
# Epoch 1/50
# 28/28 [==============================] - 1s 3ms/step - loss: 2.5193 - accuracy: 0.6696
# Epoch 2/50
# 28/28 [==============================] - 0s 3ms/step - loss: 2.2119 - accuracy: 0.6607
# Epoch 3/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1.9461 - accuracy: 0.6339
# Epoch 4/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1.7214 - accuracy: 0.6339
# Epoch 5/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1.5321 - accuracy: 0.6518
# Epoch 6/50
# 28/28 [==============================] - 0s 3ms/step - loss: 1.3823 - accuracy: 0.6696
# Epoch 7/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1.2280 - accuracy: 0.6696
# Epoch 8/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1.1090 - accuracy: 0.6696
# Epoch 9/50
# 28/28 [==============================] - 0s 2ms/step - loss: 1.0082 - accuracy: 0.6696
# Epoch 10/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.9264 - accuracy: 0.6696
# Epoch 11/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.8590 - accuracy: 0.6696
# Epoch 12/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.8043 - accuracy: 0.6696
# Epoch 13/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7579 - accuracy: 0.6696
# Epoch 14/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.7184 - accuracy: 0.6696
# Epoch 15/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6880 - accuracy: 0.6696
# Epoch 16/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6579 - accuracy: 0.6696
# Epoch 17/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6362 - accuracy: 0.6696
# Epoch 18/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6147 - accuracy: 0.6696
# Epoch 19/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.5965 - accuracy: 0.6696
# Epoch 20/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5812 - accuracy: 0.6696
# Epoch 21/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.5685 - accuracy: 0.6696
# Epoch 22/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5576 - accuracy: 0.6696
# Epoch 23/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5452 - accuracy: 0.6696
# Epoch 24/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5359 - accuracy: 0.6696
# Epoch 25/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5284 - accuracy: 0.6696
# Epoch 26/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5198 - accuracy: 0.6696
# Epoch 27/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5133 - accuracy: 0.6696
# Epoch 28/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5064 - accuracy: 0.6786
# Epoch 29/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5022 - accuracy: 0.6696
# Epoch 30/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4942 - accuracy: 0.6786
# Epoch 31/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4890 - accuracy: 0.6786
# Epoch 32/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4846 - accuracy: 0.6786
# Epoch 33/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4807 - accuracy: 0.6786
# Epoch 34/50
# 28/28 [==============================] - 0s 5ms/step - loss: 0.4761 - accuracy: 0.6786
# Epoch 35/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4719 - accuracy: 0.6786
# Epoch 36/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4685 - accuracy: 0.7232
# Epoch 37/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4655 - accuracy: 0.6875
# Epoch 38/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4618 - accuracy: 0.7232
# Epoch 39/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4573 - accuracy: 0.7232
# Epoch 40/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4518 - accuracy: 0.7232
# Epoch 41/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4488 - accuracy: 0.7500
# Epoch 42/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4389 - accuracy: 0.7946
# Epoch 43/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4294 - accuracy: 0.7857
# Epoch 44/50
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4142 - accuracy: 0.8750
# Epoch 45/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3978 - accuracy: 0.9196
# Epoch 46/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3821 - accuracy: 0.9554
# Epoch 47/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3643 - accuracy: 0.9732
# Epoch 48/50
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3496 - accuracy: 0.9821
# Epoch 49/50
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3354 - accuracy: 0.9732
# Epoch 50/50
# 28/28 [==============================] - 0s 4ms/step - loss: 0.3236 - accuracy: 0.9732
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3524 - accuracy: 0.9474
# array([0.95453095, 0.04370982, 0.00175922], dtype=float32)
