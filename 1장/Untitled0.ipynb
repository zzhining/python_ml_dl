# %%
# 코드 작성 후
# 실행(▶) 버튼을 클릭하여 실행
# 또는 shift + Enter를 함께 눌러서 실행
print('Hello Machine Learning!')

# %%
5 + 3

# %% [markdown]
# #1. 텍스트모드
# ##(1) 텍스트 작성하기
# 주피터 노트북은 텍스트도 작성이 가능합니다.
#
# ## (2) 이미지 추가하기
# <p><img alt="Colabaratory logo" src ="/img/colab_favicon.ico"</p>
